# %%
from configuration_blip import BlipVisionConfig

# %%
from modeling_blip import BlipForImageTextRetrieval
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from modeling_blip import BlipForImageTextRetrieval
#
# File F:\PHD\SAM\SAM-master\models\modeling_blip.py:37
#      28 from transformers.modeling_utils import PreTrainedModel
#      29 from transformers.utils import (
#      30     ModelOutput,
#      31     add_start_docstrings,
#    (...)
#      35     #torch_int,
#      36 )
# ---> 37 from .configuration_blip import BlipConfig, BlipTextConfig, BlipVisionConfig
#      38 from .modeling_blip_text import BlipTextLMHeadModel, BlipTextModel
#      41 logger = logging.get_logger(__name__)
#
# ImportError: attempted relative import with no known parent package
